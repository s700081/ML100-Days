# %% [markdown]
# ## Work
# 1. 試改變 monitor "Validation Accuracy" 並比較結果
# 2. 調整 earlystop 的等待次數至 10, 25 並比較結果

# %%
import os
import keras
import itertools
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization
from keras.optimizers import SGD

# Disable GPU
#os.environ["CUDA_VISIBLE_DEVICES"] = ""
#force to use cpu(by changing device_count in the tf.ContigProto)
import tensorflow as tf
from keras import backend as K
num_cores = 4
config = tf.ConfigProto(intra_op_parallelism_threads=num_cores,
                        inter_op_parallelism_threads=num_cores, 
                        allow_soft_placement=True,
                        device_count = {'CPU' : 1,
                                        'GPU' : 0}
                       )

session = tf.Session(config=config)
K.set_session(session)
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
# write function to build model
def build_mlp(input_shape,output_units=10,num_neurons=[512,128,64]):
    model=Sequential()
    model.add(Dense(units=input_shape[1], input_dim=input_shape[1],kernel_initializer='normal',activation='relu',name='input'))
    model.add(BatchNormalization()) 
    for i, n_units in enumerate(num_neurons):
        model.add(Dense(units=n_units,kernel_initializer='normal',activation='relu',name='hidden'+str(i+1)))
        model.add(BatchNormalization()) 
    model.add(Dense(units=output_units,kernel_initializer='normal',activation='softmax',name='output'))
    return model

# %%
# write function to plot results
def plot_results(results):
    color_bar=['slateblue','green','red','greenyellow','sienna','lime','maroon','aqua','dodgerblue','mediumblue','darkorchid','purple']
    """
    Draw the results
    """
    plt.figure(figsize=(12,9))
    for i, cond in enumerate(results.keys()):
        plt.plot(range(len(results[cond]['train_loss'])), results[cond]['train_loss'], '-', label='train:'+cond, color=color_bar[i%12])
        plt.plot(range(len(results[cond]['valid_loss'])), results[cond]['valid_loss'],'--', label='valid:'+cond, color=color_bar[i%12])
    plt.title('Loss')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show

    plt.figure(figsize=(12,9))
    for i, cond in enumerate(results.keys()):
        plt.plot(range(len(results[cond]['train_acc'])), results[cond]['train_acc'], '-', label='train:'+cond, color=color_bar[i%12])
        plt.plot(range(len(results[cond]['valid_acc'])), results[cond]['valid_acc'],'--', label='valid:'+cond, color=color_bar[i%12])
    plt.title('Accuracy')
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()

# %%
## 超參數設定
"""
Set your hyper-parameters
"""
LEARNING_RATE=1e-3
EPOCHS=30
BATCH_SIZE=256
MOMENTUM=0.9

# %% [markdown]
# ## 作業一、改成monitor val_acc

# %%
# 載入 Callbacks
"""
Earlystop setting ()
"""
from keras.callbacks import EarlyStopping
earlystop = EarlyStopping(monitor="val_acc", patience=5, verbose=1 )
"""
Your Training loop and Plot the results
"""
results_hw1={}
for monitor_opt in ['yes','no']:
    model=build_mlp(input_shape=x_train.shape)
    model.summary()
    optimizer=SGD(lr=LEARNING_RATE,nesterov=True, momentum=MOMENTUM)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
    
    if monitor_opt =='yes':
        model.fit(x_train,y_train,
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  validation_data=(x_test,y_test),
                  shuffle=True,
                  callbacks=[earlystop])
    elif monitor_opt =='no':
        model.fit(x_train,y_train,
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  validation_data=(x_test,y_test),
                  shuffle=True)
    
    # collect results
    train_loss=model.history.history['loss']
    valid_loss=model.history.history['val_loss']
    train_acc=model.history.history['acc']
    valid_acc=model.history.history['val_acc']
    
    # construct dictionary
    exp_name_tag = 'exp_%s'%str('earlystop')+str(monitor_opt)
        
    results_hw1[exp_name_tag]={'train_loss':train_loss,
                               'valid_loss':valid_loss,
                               'train_acc':train_acc,
                               'valid_acc':valid_acc}
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3072)              12288
# _________________________________________________________________
# hidden1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 512)               2048
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# hidden3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64)                256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 11,103,306
# Trainable params: 11,095,754
# Non-trainable params: 7,552
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 51s 1ms/step - loss: 2.0619 - acc: 0.2586 - val_loss: 1.8697 - val_acc: 0.3241
# Epoch 2/30
# 50000/50000 [==============================] - 50s 1ms/step - loss: 1.8024 - acc: 0.3597 - val_loss: 1.7393 - val_acc: 0.3805
# Epoch 3/30
# 50000/50000 [==============================] - 50s 999us/step - loss: 1.6833 - acc: 0.4035 - val_loss: 1.6625 - val_acc: 0.4117
# Epoch 4/30
# 50000/50000 [==============================] - 50s 996us/step - loss: 1.6000 - acc: 0.4324 - val_loss: 1.6116 - val_acc: 0.4287
# Epoch 5/30
# 50000/50000 [==============================] - 49s 982us/step - loss: 1
30
# 50000/50000 [==============================] - 49s 979us/step - loss: 1.4230 - acc: 0.4942 - val_loss: 1.5143 - val_acc: 0.4588
# Epoch 8/30
# 50000/50000 [==============================] - 49s 980us/step - loss: 1.3772 - acc: 0.5109 - val_loss: 1.4960 - val_acc: 0.4669
# Epoch 9/30
# 50000/50000 [==============================] - 49s 975us/step - loss: 1.3322 - acc: 0.5292 - val_loss: 1.4834 - val_acc: 0.4762
# Epoch 10/30
# 50000/50000 [==============================] - 49s 976us/step - loss: 1.2889 - acc: 0.5442 - val_loss: 1.4768 - val_acc: 0.4739
# Epoch 11/30
# 50000/50000 [==============================] - 49s 978us/step - loss: 1.2459 - acc: 0.5614 - val_loss: 1.4690 - val_acc: 0.4783
# Epoch 12/30
# 50000/50000 [==============================] - 49s 976us/step - loss: 1.2050 - acc: 0.5758 - val_loss: 1.4699 - val_acc: 0.4816
# Epoch 13/30
# 50000/50000 [==============================] - 49s 977us/step - loss: 1.1648 - acc: 0.5909 - val_loss: 1.4751 - val_acc: 0.4803
# Epoch 14/30
# 50000/50000 [==============================] - 49s 976us/step - loss: 1.1229 - acc: 0.6062 - val_loss: 1.4783 - val_acc: 0.4837
# Epoch 15/30
# 50000/50000 [==============================] - 49s 977us/step - loss: 1.0855 - acc: 0.6199 - val_loss: 1.4821 - val_acc: 0.4889
# Epoch 16/30
# 50000/50000 [==============================] - 49s 975us/step - loss: 1.0436 - acc: 0.6358 - val_loss: 1.4889 - val_acc: 0.4884
# Epoch 17/30
# 50000/50000 [==============================] - 49s 977us/step - loss: 1.0029 - acc: 0.6519 - val_loss: 1.5103 - val_acc: 0.4825
# Epoch 18/30
# 50000/50000 [==============================] - 49s 976us/step - loss: 0.9636 - acc: 0.6661 - val_loss: 1.5139 - val_acc: 0.4821
# Epoch 19/30
# 50000/50000 [==============================] - 49s 977us/step - loss: 0.9225 - acc: 0.6819 - val_loss: 1.5256 - val_acc: 0.4823
# Epoch 20/30
# 50000/50000 [==============================] - 49s 977us/step - loss: 0.8822 - acc: 0.6962 - val_loss: 1.5433 - val_acc: 0.4865
# Epoch 21/30
# 50000/50000 [==============================] - 49s 976us/step - loss: 0.8418 - acc: 0.7124 - val_loss: 1.5639 - val_acc: 0.4854
# Epoch 22/30
# 50000/50000 [==============================] - 49s 979us/step - loss: 0.8025 - acc: 0.7277 - val_loss: 1.5984 - val_acc: 0.4806
# Epoch 23/30
# 50000/50000 [==============================] - 49s 982us/step - loss: 0.7673 - acc: 0.7388 - val_loss: 1.6120 - val_acc: 0.4868
# Epoch 24/30
# 50000/50000 [==============================] - 49s 978us/step - loss: 0.7259 - acc: 0.7563 - val_loss: 1.6239 - val_acc: 0.4861
# Epoch 25/30
# 50000/50000 [==============================] - 49s 977us/step - loss: 0.6846 - acc: 0.7706 - val_loss: 1.6771 - val_acc: 0.4816
# Epoch 26/30
# 50000/50000 [==============================] - 49s 976us/step - loss: 0.6476 - acc: 0.7850 - val_loss: 1.7002 - val_acc: 0.4777
# Epoch 27/30
# 50000/50000 [==============================] - 49s 980us/step - loss: 0.6139 - acc: 0.7983 - val_loss: 1.7259 - val_acc: 0.4809
# Epoch 28/30
# 50000/50000 [==============================] - 49s 977us/step - loss: 0.5731 - acc: 0.8125 - val_loss: 1.7670 - val_acc: 0.4826
# Epoch 29/30
# 50000/50000 [==============================] - 49s 976us/step - loss: 0.5397 - acc: 0.8270 - val_loss: 1.8146 - val_acc: 0.4776
# Epoch 30/30
# 50000/50000 [==============================] - 49s 980us/step - loss: 0.5067 - acc: 0.8374 - val_loss: 1.8187 - val_acc: 0.4759

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plot_results(results_hw1)

# %%
## 作業二、調整 earlystop 的等待次數至 10, 25
WAITTIME=[5,10,25]
results_hw2={}
for waittime in WAITTIME:
    earlystop = EarlyStopping(monitor="val_acc", patience=waittime, verbose=1 )
    model=build_mlp(input_shape=x_train.shape)
    model.summary()
    optimizer=SGD(lr=LEARNING_RATE,nesterov=True, momentum=MOMENTUM)
    model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
    model.fit(x_train,y_train,
                  epochs=EPOCHS,
                  batch_size=BATCH_SIZE,
                  validation_data=(x_test,y_test),
                  shuffle=True,
                  callbacks=[earlystop])
    
    # collect results
    train_loss=model.history.history['loss']
    valid_loss=model.history.history['val_loss']
    train_acc=model.history.history['acc']
    valid_acc=model.history.history['val_acc']
    
    # construct dictionary
    exp_name_tag = 'exp_%s'%str('wait-time')+str(waittime)
        
    results_hw2[exp_name_tag]={'train_loss':train_loss,
                               'valid_loss':valid_loss,
                               'train_acc':train_acc,
                               'valid_acc':valid_acc}
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 3072)              12288
# _________________________________________________________________
# hidden1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 128)               512
# _________________________________________________________________
# hidden3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64)                256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 11,103,306
# Trainable params: 11,095,754
# Non-trainable params: 7,552
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 52s 1ms/step - loss: 2.0685 - acc: 0.2572 - val_loss: 1.8848 - val_acc: 0.3268
# Epoch 2/30
# 50000/50000 [==============================] - 50s 997us/step - loss: 1.8116 - acc: 0.3606 - val_loss: 1.7511 - val_acc: 0.3743
# Epoch 3/30
# 50000/50000 [==============================] - 50s 999us/step - loss: 1.6871 - acc: 0.4035 - val_loss: 1.6686 - val_acc: 0.4038
# Epoch 4/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 1.6010 - acc: 0.4354 - val_loss: 1.6122 - val_acc: 0.4251
# Epoch 5/30
# 50000/50000 [==============================] - 49s 985us/step - loss: 1.5350 - acc: 0.4576 - val_loss: 1.5796 - val_acc: 0.4396
# Epoch 6/30
# 50000/50000 [==============================] - 49s 985us/step - loss: 1.4777 - acc: 0.4799 - val_loss: 1.5468 - val_acc: 0.4512
# Epoch 7/30
# 50000/50000 [==============================] - 49s 983us/step - loss: 1.4284 - acc: 0.4963 - val_loss: 1.5295 - val_acc: 0.4583
# Epoch 8/30
# 50000/50000 [==============================] - 49s 983us/step - loss: 1.3798 - acc: 0.5144 - val_loss: 1.5144 - val_acc: 0.4663
# Epoch 9/30
# 50000/50000 [==============================] - 49s 985us/step - loss: 1.3370 - acc: 0.5285 - val_loss: 1.4944 - val_acc: 0.4711
# Epoch 10/30
# 50000/50000 [==============================] - 49s 985us/step - loss: 1.2961 - acc: 0.5436 - val_loss: 1.4873 - val_acc: 0.4772
# Epoch 11/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 1.2529 - acc: 0.5610 - val_loss: 1.4868 - val_acc: 0.4794
# Epoch 12/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 1.2138 - acc: 0.5734 - val_loss: 1.4794 - val_acc: 0.4824
# Epoch 13/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 1.1749 - acc: 0.5889 - val_loss: 1.4779 - val_acc: 0.4833
# Epoch 14/30
# 50000/50000 [==============================] - 49s 986us/step - loss: 1.1324 - acc: 0.6047 - val_loss: 1.4853 - val_acc: 0.4855
# Epoch 15/30
# 50000/50000 [==============================] - 49s 985us/step - loss: 1.0941 - acc: 0.6182 - val_loss: 1.4904 - val_acc: 0.4837
# Epoch 16/30
# 50000/50000 [==============================] - 49s 989us/step - loss: 1.0520 - acc: 0.6348 - val_loss: 1.4968 - val_acc: 0.4837
# Epoch 17/30
# 50000/50000 [==============================] - 49s 986us/step - loss: 1.0150 - acc: 0.6461 - val_loss: 1.5042 - val_acc: 0.4832
# Epoch 18/30
# 50000/50000 [==============================] - 49s 988us/step - loss: 0.9746 - acc: 0.6641 - val_loss: 1.5131 - val_acc: 0.4881
# Epoch 19/30
# 50000/50000 [==============================] - 49s 987us/step - loss: 0.9343 - acc: 0.6761 - val_loss: 1.5291 - val_acc: 0.4834
# Epoch 20/30
# 50000/50000 [==============================] - 49s 985us/step - loss: 0.8941 - acc: 0.6924 - val_loss: 1.5555 - val_acc: 0.4793
# Epoch 21/30
# 50000/50000 [==============================] - 49s 988us/step - loss: 0.8560 - acc: 0.7057 - val_loss: 1.5583 - val_acc: 0.4868
# Epoch 22/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 0.8180 - acc: 0.7207 - val_loss: 1.5897 - val_acc: 0.4791
# Epoch 23/30
# 50000/50000 [==============================] - 49s 987us/step - loss: 0.7776 - acc: 0.7372 - val_loss: 1.6030 - val_acc: 0.4863
# Epoch 00023: early stopping
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 3072)              9440256
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 3072)              12288
# _________________________________________________________________
# hidden1 (Dense)              (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden2 (Dense)              (None, 128)               65664
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 128)               512
# _________________________________________________________________
# hidden3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 64)                256
# _________________________________________________________________
# output (Dense)               (None, 10)                650
# =================================================================
# Total params: 11,103,306
# Trainable params: 11,095,754
# Non-trainable params: 7,552
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/30
# 50000/50000 [==============================] - 51s 1ms/step - loss: 2
30
# 50000/50000 [==============================] - 49s 982us/step - loss: 1.5277 - acc: 0.4601 - val_loss: 1.5670 - val_acc: 0.4409
# Epoch 6/30
# 50000/50000 [==============================] - 49s 983us/step - loss: 1.4726 - acc: 0.4797 - val_loss: 1.5364 - val_acc: 0.4486
# Epoch 7/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 1.4230 - acc: 0.4986 - val_loss: 1.5151 - val_acc: 0.4563
# Epoch 8/30
# 50000/50000 [==============================] - 49s 987us/step - loss: 1.3771 - acc: 0.5141 - val_loss: 1.4986 - val_acc: 0.4619
# Epoch 9/30
# 50000/50000 [==============================] - 49s 980us/step - loss: 1.3342 - acc: 0.5297 - val_loss: 1.4829 - val_acc: 0.4697
# Epoch 10/30
# 50000/50000 [==============================] - 50s 995us/step - loss: 1.2899 - acc: 0.5467 - val_loss: 1.4754 - val_acc: 0.4758
# Epoch 11/30
# 50000/50000 [==============================] - 50s 1ms/step - loss: 1.2494 - acc: 0.5595 - val_loss: 1.4687 - val_acc: 0.4747
# Epoch 12/30
# 50000/50000 [==============================] - 50s 1ms/step - loss: 1.2079 - acc: 0.5746 - val_loss: 1.4665 - val_acc: 0.4794
# Epoch 13/30
# 50000/50000 [==============================] - 49s 987us/step - loss: 1.1679 - acc: 0.5879 - val_loss: 1.4659 - val_acc: 0.4771
# Epoch 14/30
# 50000/50000 [==============================] - 49s 981us/step - loss: 1.1302 - acc: 0.6021 - val_loss: 1.4720 - val_acc: 0.4822
# Epoch 15/30
# 50000/50000 [==============================] - 49s 979us/step - loss: 1.0882 - acc: 0.6182 - val_loss: 1.4713 - val_acc: 0.4837
# Epoch 16/30
# 50000/50000 [==============================] - 50s 1ms/step - loss: 1.0519 - acc: 0.6329 - val_loss: 1.4756 - val_acc: 0.4824
# Epoch 17/30
# 50000/50000 [==============================] - 51s 1ms/step - loss: 1.0121 - acc: 0.6486 - val_loss: 1.4992 - val_acc: 0.4822
# Epoch 18/30
# 50000/50000 [==============================] - 50s 1ms/step - loss: 0.9714 - acc: 0.6630 - val_loss: 1.4976 - val_acc: 0.4872
# Epoch 19/30
# 50000/50000 [==============================] - 50s 1ms/step - loss: 0.9305 - acc: 0.6774 - val_loss: 1.5268 - val_acc: 0.4779
# Epoch 20/30
# 50000/50000 [==============================] - 49s 982us/step - loss: 0.8905 - acc: 0.6930 - val_loss: 1.5314 - val_acc: 0.4801
# Epoch 21/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 0.8515 - acc: 0.7062 - val_loss: 1.5574 - val_acc: 0.4818
# Epoch 22/30
# 50000/50000 [==============================] - 49s 983us/step - loss: 0.8122 - acc: 0.7233 - val_loss: 1.5785 - val_acc: 0.4799
# Epoch 23/30
# 50000/50000 [==============================] - 50s 998us/step - loss: 0.7719 - acc: 0.7372 - val_loss: 1.5977 - val_acc: 0.4836
# Epoch 24/30
# 50000/50000 [==============================] - 52s 1ms/step - loss: 0.7342 - acc: 0.7508 - val_loss: 1.6128 - val_acc: 0.4799
# Epoch 25/30
# 50000/50000 [==============================] - 53s 1ms/step - loss: 0.6945 - acc: 0.7674 - val_loss: 1.6599 - val_acc: 0.4748
# Epoch 26/30
# 50000/50000 [==============================] - 56s 1ms/step - loss: 0.6576 - acc: 0.7811 - val_loss: 1.6961 - val_acc: 0.4778
# Epoch 27/30
# 50000/50000 [==============================] - 54s 1ms/step - loss: 0.6218 - acc: 0.7933 - val_loss: 1.7082 - val_acc: 0.4740
# Epoch 28/30
# 50000/50000 [==============================] - 49s 984us/step - loss: 0.5840 - acc: 0.8102 - val_loss: 1.7434 - val_acc: 0.4750
# Epoch 29/30
# 50000/50000 [==============================] - 50s 991us/step - loss: 0.5461 - acc: 0.8217 - val_loss: 1.8178 - val_acc: 0.4686
# Epoch 30/30
# 50000/50000 [==============================] - 50s 1ms/step - loss: 0.5137 - acc: 0.8351 - val_loss: 1.8305 - val_acc: 0.4638

# %%
plot_results(results_hw2)
