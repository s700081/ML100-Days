# %% [markdown]
# # 作業:
#
#     (1)以, Adam, 為例, 調整 batch_size, epoch , 觀察accurancy, loss 的變化
#
#     (2)以同一模型, 分別驗證 SGD, Adam, Rmsprop 的 accurancy

# %% [markdown]
# ## 作業一 以Adam為例, 調整 batch_size, epoch, 觀察accurancy, loss 的變化

# %%
import keras
#from keras.datasets import cifar10
from keras.datasets import mnist 
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import optimizers
from keras.callbacks import EarlyStopping, ModelCheckpoint
import numpy
# Out:
# Using TensorFlow backend.

# %%
# 第一步：資料分割
# 使用Keras自帶的mnist工具讀取數據（第一次需要聯網）
(X_train, y_train), (X_test, y_test) = mnist.load_data() 

# 由於mist的輸入數據維度是(num, 28 , 28)，這裡需要把後面的維度直接拼起來變成784維   
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2 ])
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2 ])  
Y_train = (numpy.arange(10) == y_train[:, None]).astype(int)
Y_test = (numpy.arange(10) == y_test[:, None]).astype(int)

# %%
# 第二步：選擇模型, 順序模型是多個網絡層的線性堆疊
 
model = Sequential()

# 第三步：構建網絡層
 
model.add(Dense( 500,input_shape=(784,))) # 輸入層，28*28=784   
model.add(Activation('relu')) # 激活函數是relu   

model.add(Dense( 500)) # 隱藏層節點500個   
model.add(Activation('relu'))  

model.add(Dense( 500)) # 隱藏層節點500個   
model.add(Activation('relu'))  

model.add(Dense( 500)) # 隱藏層節點500個   
model.add(Activation('relu'))  

model.add(Dense( 10)) # 輸出結果是10個類別，所以維度是10   
model.add(Activation('softmax')) # 最後一層用softmax作為激活函數
# Out:
# WARNING:tensorflow:From C:\Users\Ocean\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# 模型建立完成後，統計參數總量
print("Total Parameters：%d" % model.count_params())
# Out:
# Total Parameters：1149010

# %%
# 輸出模型摘要資訊
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 500)               392500
# _________________________________________________________________
# activation_1 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 500)               250500
# _________________________________________________________________
# activation_2 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 500)               250500
# _________________________________________________________________
# activation_3 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 500)               250500
# _________________________________________________________________
# activation_4 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                5010
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,149,010
# Trainable params: 1,149,010
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  '''
#  SGD(隨機梯度下降) - Arguments
# lr: float >= 0. Learning rate.
# momentum: float >= 0. Parameter that accelerates SGD in the relevant direction and dampens oscillations.
# decay: float >= 0. Learning rate decay over each update.
# nesterov: boolean. Whether to apply Nesterov momentum.
# '''
#
# '''
# RMSprop- Arguments
# lr: float >= 0. Learning rate.
# rho: float >= 0.
# epsilon: float >= 0. Fuzz factor. If None, defaults to K.epsilon().
# decay: float >= 0. Learning rate decay over each update.
# '''

# %% [markdown]
# ## Adam

# %%
# 第四步：編譯, Adam
model.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# 第五步：訓練, 修正 model 參數
#Blas GEMM launch failed , 避免動態分配GPU / CPU, 出現問題
'''
   宣告並設定
   batch_size：對總的樣本數進行分組，每組包含的樣本數量
   epochs ：訓練次數
   
''' 
batch_size=[512,1024]
epochs = [10,20]

history_assembly=[]

#import tensorflow as tf
for batch in batch_size:
    for epoch in epochs:
        print(f"epochs={epoch}. batch_size={batch}.")
        #gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.333)
        #sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
        history = model.fit(X_train,Y_train,batch_size = batch, epochs=epoch, shuffle=True,verbose=2,validation_split=0.3 )
        history_assembly.append(history)
        history=[]
        scores = model.evaluate(X_test,Y_test,batch_size=200,verbose= 0)
        print (f"test loss: {scores}" )
        result = model.predict(X_test,batch_size=200,verbose= 0)
        result_max = numpy.argmax(result, axis = 1 )
        test_max = numpy.argmax(Y_test, axis = 1 )
        result_bool = numpy.equal(result_max, test_max)
        true_num = numpy.sum(result_bool)
        print (f"model accuracy: {true_num/len(result_bool)}")
# Out:
# epochs=10. batch_size=512.
# WARNING:tensorflow:From C:\Users\Ocean\Anaconda3\envs\py36\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/10
#  - 4s - loss: 2.8779 - acc: 0.8196 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 2/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 3/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 4/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 5/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 6/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 7/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 8/10
#  - 4s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 9/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 10/10
#  - 4s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# test loss: [2.8912143421173098, 0.8196396505832673]
# model accuracy: 0.0982
# epochs=20. batch_size=512.
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 2/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 3/20
#  - 4s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 4/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 5/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 6/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 7/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 8/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 9/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 10/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 11/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 12/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 13/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 14/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 15/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 16/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 17/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 18/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 19/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 20/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# test loss: [2.8912143421173098, 0.8196396505832673]
# model accuracy: 0.0982
# epochs=10. batch_size=1024.
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 2/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 3/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 4/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 5/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 6/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 7/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 8/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 9/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 10/10
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# test loss: [2.8912143421173098, 0.8196396505832673]
# model accuracy: 0.0982
# epochs=20. batch_size=1024.
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 2/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 3/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 4/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 5/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 6/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 7/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 8/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 9/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 10/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 11/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 12/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 13/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 14/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 15/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 16/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 17/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 18/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 19/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# Epoch 20/20
#  - 3s - loss: 2.8932 - acc: 0.8195 - val_loss: 2.8956 - val_acc: 0.8194
# test loss: [2.8912143421173098, 0.8196396505832673]
# model accuracy: 0.0982

# %%
# 第六步：輸出
 
import matplotlib.pyplot as plt

# %matplotlib inline

# Plot training & validation accuracy values
plt.figure(figsize=(15,10))

k=0
for i in range(2):
    for j in range(2):
        plt.subplot(2,2,k+1)
        plt.plot(history_assembly[k].history['acc'])
        plt.plot(history_assembly[k].history['val_acc'])
        plt.title('Model accuracy for ' + 'batch_size :'+ str(batch_size[i]) +'  epochs :' + str(epochs[j]))
        plt.ylabel('Accuracy')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='best')
        k+=1
        
plt.show()

# %%
# Plot training & validation loss values
plt.figure(figsize=(15,10))

k=0
for i in range(2):
    for j in range(2):
        plt.subplot(2,2,k+1)
        plt.plot(history_assembly[k].history['loss'])
        plt.plot(history_assembly[k].history['val_loss'])
        plt.title('Model loss for ' + 'batch_size :'+ str(batch_size[i]) +'  epochs :' + str(epochs[j]))
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='best')
        k+=1
        
plt.show()

# %% [markdown]
# ## 作業二 以同一模型, 分別驗證 SGD, Adam, Rmsprop 的 accurancy

# %%
# construct a model
model = Sequential()
 
model.add(Dense( 500,input_shape=(784,))) # 輸入層，28*28=784   
model.add(Activation('relu')) # 激活函數是relu   

model.add(Dense( 500)) # 隱藏層節點500個   
model.add(Activation('relu'))  


model.add(Dense( 10)) # 輸出結果是10個類別，所以維度是10   
model.add(Activation('softmax')) # 最後一層用softmax作為激活函數

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 500)               392500
# _________________________________________________________________
# activation_6 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 500)               250500
# _________________________________________________________________
# activation_7 (Activation)    (None, 500)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5010
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# =================================================================
# Total params: 648,010
# Trainable params: 648,010
# Non-trainable params: 0
# _________________________________________________________________

# %%
# function to compile and fit model
def fit_model(model, opt):
    model.compile(optimizer = opt, loss = 'binary_crossentropy', metrics = ['accuracy'])
    history = model.fit(X_train,Y_train,batch_size = 512, epochs=20, shuffle=True,verbose=2,validation_split=0.3 )
    return history

# %%
# function to 
def plot_output(history,opt):
    plt.figure(figsize=(15,5))
    plt.subplot(1,2,1)
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('Model accuracy for batch_size:512  epochs:20  optimizer:'+opt)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
              
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss for batch_size:512  epochs:20  optimizer:'+opt)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Test'], loc='best')
    plt.show()

# %%
optimizers = ['SGD', 'Adam', 'Rmsprop']

for opt in optimizers:
    history= fit_model(model, opt)
    plot_output(history,opt)
# Out:
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
#  - 2s - loss: 0.0541 - acc: 0.9959 - val_loss: 0.0834 - val_acc: 0.9938
# Epoch 2/20
#  - 2s - loss: 0.0441 - acc: 0.9968 - val_loss: 0.0810 - val_acc: 0.9940
# Epoch 3/20
#  - 2s - loss: 0.0404 - acc: 0.9971 - val_loss: 0.0798 - val_acc: 0.9940
# Epoch 4/20
#  - 2s - loss: 0.0384 - acc: 0.9973 - val_loss: 0.0830 - val_acc: 0.9938
# Epoch 5/20
#  - 2s - loss: 0.0394 - acc: 0.9972 - val_loss: 0.0795 - val_acc: 0.9940
# Epoch 6/20
#  - 2s - loss: 0.0365 - acc: 0.9975 - val_loss: 0.0795 - val_acc: 0.9941
# Epoch 7/20
#  - 2s - loss: 0.0356 - acc: 0.9975 - val_loss: 0.0791 - val_acc: 0.9942
# Epoch 8/20
#  - 2s - loss: 0.0350 - acc: 0.9976 - val_loss: 0.0792 - val_acc: 0.9941
# Epoch 9/20
#  - 2s - loss: 0.0342 - acc: 0.9977 - val_loss: 0.0788 - val_acc: 0.9941
# Epoch 10/20
#  - 2s - loss: 0.0339 - acc: 0.9977 - val_loss: 0.0786 - val_acc: 0.9941
# Epoch 11/20
#  - 2s - loss: 0.0336 - acc: 0.9977 - val_loss: 0.0788 - val_acc: 0.9941
# Epoch 12/20
#  - 2s - loss: 0.0334 - acc: 0.9978 - val_loss: 0.0788 - val_acc: 0.9940
# Epoch 13/20
#  - 2s - loss: 0.0334 - acc: 0.9978 - val_loss: 0.0783 - val_acc: 0.9941
# Epoch 14/20
#  - 2s - loss: 0.0333 - acc: 0.9978 - val_loss: 0.0786 - val_acc: 0.9941
# Epoch 15/20
#  - 2s - loss: 0.0333 - acc: 0.9978 - val_loss: 0.0782 - val_acc: 0.9941
# Epoch 16/20
#  - 2s - loss: 0.0333 - acc: 0.9978 - val_loss: 0.0782 - val_acc: 0.9941
# Epoch 17/20
#  - 2s - loss: 0.0332 - acc: 0.9978 - val_loss: 0.0781 - val_acc: 0.9941
# Epoch 18/20
#  - 2s - loss: 0.0332 - acc: 0.9978 - val_loss: 0.0781 - val_acc: 0.9941
# Epoch 19/20
#  - 2s - loss: 0.0331 - acc: 0.9978 - val_loss: 0.0780 - val_acc: 0.9941
# Epoch 20/20
#  - 2s - loss: 0.0331 - acc: 0.9978 - val_loss: 0.0781 - val_acc: 0.9941
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
#  - 3s - loss: 0.0850 - acc: 0.9937 - val_loss: 0.1396 - val_acc: 0.9900
# Epoch 2/20
#  - 2s - loss: 0.1102 - acc: 0.9921 - val_loss: 0.1263 - val_acc: 0.9914
# Epoch 3/20
#  - 2s - loss: 0.0976 - acc: 0.9930 - val_loss: 0.1361 - val_acc: 0.9905
# Epoch 4/20
#  - 2s - loss: 0.0861 - acc: 0.9939 - val_loss: 0.1195 - val_acc: 0.9915
# Epoch 5/20
#  - 2s - loss: 0.0880 - acc: 0.9938 - val_loss: 0.1159 - val_acc: 0.9919
# Epoch 6/20
#  - 2s - loss: 0.0794 - acc: 0.9945 - val_loss: 0.1168 - val_acc: 0.9919
# Epoch 7/20
#  - 2s - loss: 0.0797 - acc: 0.9944 - val_loss: 0.1114 - val_acc: 0.9923
# Epoch 8/20
#  - 2s - loss: 0.0835 - acc: 0.9942 - val_loss: 0.1281 - val_acc: 0.9913
# Epoch 9/20
#  - 2s - loss: 0.0814 - acc: 0.9944 - val_loss: 0.1228 - val_acc: 0.9916
# Epoch 10/20
#  - 2s - loss: 0.0815 - acc: 0.9944 - val_loss: 0.1276 - val_acc: 0.9913
# Epoch 11/20
#  - 2s - loss: 0.0813 - acc: 0.9944 - val_loss: 0.1224 - val_acc: 0.9917
# Epoch 12/20
#  - 2s - loss: 0.0829 - acc: 0.9943 - val_loss: 0.1242 - val_acc: 0.9915
# Epoch 13/20
#  - 2s - loss: 0.1058 - acc: 0.9929 - val_loss: 0.1252 - val_acc: 0.9916
# Epoch 14/20
#  - 2s - loss: 0.1016 - acc: 0.9932 - val_loss: 0.1372 - val_acc: 0.9910
# Epoch 15/20
#  - 2s - loss: 0.0922 - acc: 0.9937 - val_loss: 0.1339 - val_acc: 0.9911
# Epoch 16/20
#  - 2s - loss: 0.0857 - acc: 0.9943 - val_loss: 0.1154 - val_acc: 0.9923
# Epoch 17/20
#  - 2s - loss: 0.0856 - acc: 0.9943 - val_loss: 0.1205 - val_acc: 0.9921
# Epoch 18/20
#  - 2s - loss: 0.0879 - acc: 0.9942 - val_loss: 0.1183 - val_acc: 0.9922
# Epoch 19/20
#  - 2s - loss: 0.0899 - acc: 0.9940 - val_loss: 0.1188 - val_acc: 0.9921
# Epoch 20/20
#  - 2s - loss: 0.0867 - acc: 0.9943 - val_loss: 0.1292 - val_acc: 0.9915
# Train on 42000 samples, validate on 18000 samples
# Epoch 1/20
#  - 3s - loss: 0.0831 - acc: 0.9946 - val_loss: 0.1052 - val_acc: 0.9931
# Epoch 2/20
#  - 2s - loss: 0.0694 - acc: 0.9954 - val_loss: 0.1051 - val_acc: 0.9931
# Epoch 3/20
#  - 2s - loss: 0.0741 - acc: 0.9952 - val_loss: 0.1241 - val_acc: 0.9918
# Epoch 4/20
#  - 2s - loss: 0.0674 - acc: 0.9956 - val_loss: 0.1117 - val_acc: 0.9926
# Epoch 5/20
#  - 2s - loss: 0.0642 - acc: 0.9957 - val_loss: 0.1004 - val_acc: 0.9935
# Epoch 6/20
#  - 2s - loss: 0.0636 - acc: 0.9958 - val_loss: 0.1344 - val_acc: 0.9912
# Epoch 7/20
#  - 2s - loss: 0.0699 - acc: 0.9954 - val_loss: 0.0933 - val_acc: 0.9939
# Epoch 8/20
#  - 2s - loss: 0.0688 - acc: 0.9955 - val_loss: 0.1297 - val_acc: 0.9914
# Epoch 9/20
#  - 2s - loss: 0.0678 - acc: 0.9955 - val_loss: 0.1000 - val_acc: 0.9935
# Epoch 10/20
#  - 2s - loss: 0.0603 - acc: 0.9960 - val_loss: 0.1051 - val_acc: 0.9932
# Epoch 11/20
#  - 2s - loss: 0.0738 - acc: 0.9952 - val_loss: 0.0988 - val_acc: 0.9936
# Epoch 12/20
#  - 2s - loss: 0.0659 - acc: 0.9957 - val_loss: 0.1137 - val_acc: 0.9926
# Epoch 13/20
#  - 2s - loss: 0.0611 - acc: 0.9960 - val_loss: 0.1043 - val_acc: 0.9932
# Epoch 14/20
#  - 2s - loss: 0.0621 - acc: 0.9960 - val_loss: 0.1056 - val_acc: 0.9932
# Epoch 15/20
#  - 2s - loss: 0.0575 - acc: 0.9962 - val_loss: 0.1053 - val_acc: 0.9932
# Epoch 16/20
#  - 2s - loss: 0.0591 - acc: 0.9962 - val_loss: 0.1058 - val_acc: 0.9932
# Epoch 17/20
#  - 2s - loss: 0.0594 - acc: 0.9961 - val_loss: 0.1210 - val_acc: 0.9921
# Epoch 18/20
#  - 2s - loss: 0.0599 - acc: 0.9961 - val_loss: 0.0941 - val_acc: 0.9939
# Epoch 19/20
#  - 2s - loss: 0.0561 - acc: 0.9964 - val_loss: 0.1066 - val_acc: 0.9931
# Epoch 20/20
#  - 2s - loss: 0.0603 - acc: 0.9961 - val_loss: 0.0935 - val_acc: 0.9940
